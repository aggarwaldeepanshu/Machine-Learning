# %%
import numpy as np
import pandas as pd
import os

# %%
train_df=pd.read_csv("/home/deepanshu/titanic/train.csv",index_col="PassengerId")
test_df=pd.read_csv("/home/deepanshu/titanic/test.csv",index_col="PassengerId")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
test_df['Survived']=-888

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 11 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# Survived    418 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
df=pd.concat((train_df,test_df),axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.head(10)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...

# %%
df[['Name','Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...

# %%
df.loc[2:8,'Name':'Survived']
# Out:
#                                                           Name  Parch  Pclass  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
#
#                 Sex  SibSp  Survived
# PassengerId
# 2            female      1         1
# 3            female      0         1
# 4            female      1         1
# 5              male      0         0
# 6              male      0         0
# 7              male      0         0
# 8              male      3         0

# %%
df.loc[2:8,['Name','Pclass','Sex','Survived']]
# Out:
#                                                           Name  Pclass  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3                                       Heikkinen, Miss. Laina       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 5                                     Allen, Mr. William Henry       3
# 6                                             Moran, Mr. James       3
# 7                                      McCarthy, Mr. Timothy J       1
# 8                               Palsson, Master. Gosta Leonard       3
#
#                 Sex  Survived
# PassengerId
# 2            female         1
# 3            female         1
# 4            female         1
# 5              male         0
# 6              male         0
# 7              male         0
# 8              male         0

# %%
number_of_male=df.loc[df.Sex=='male',:]
print("Number of male passengers is : {0}".format(len(number_of_male)))
# Out:
# Number of male passengers is : 843

# %%
number_of_male=df.loc[((df.Sex=='male') & (df.Pclass==1) ),:]
print("Number of male passengers is : {0}".format(len(number_of_male)))
# Out:
# Number of male passengers is : 179

# %%
df.describe()
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#           Survived
# count  1309.000000
# mean   -283.301757
# std     414.337413
# min    -888.000000
# 25%    -888.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
print("Mean fare is: {0}".format(df.Fare.mean()))
# Out:
# Mean fare is: 33.2954792813

# %%
print("range in age is: {0}".format(df.Age.max()-df.Age.min()))
# Out:
# range in age is: 79.83

# %%
print("Min age is: {0}".format(df.Age.min()))
print("Max age is: {0}".format(df.Age.max()))
# Out:
# Min age is: 0.17
# Max age is: 80.0

# %%
# %matplotlib inline

# %%
df.Fare.plot(kind='box')

# %%
df.describe(include='all')
# Out:
#                 Age        Cabin Embarked         Fare                  Name  \
# count   1046.000000          295     1307  1308.000000                  1309
# unique          NaN          186        3          NaN                  1307
# top             NaN  C23 C25 C27        S          NaN  Connolly, Miss. Kate
# freq            NaN            6      914          NaN                     2
# mean      29.881138          NaN      NaN    33.295479                   NaN
# std       14.413493          NaN      NaN    51.758668                   NaN
# min        0.170000          NaN      NaN     0.000000                   NaN
# 25%       21.000000          NaN      NaN     7.895800                   NaN
# 50%       28.000000          NaN      NaN    14.454200                   NaN
# 75%       39.000000          NaN      NaN    31.275000                   NaN
# max       80.000000          NaN      NaN   512.329200                   NaN
#
# ...

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(normalize=True)
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
df[df.Survived!=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df.Survived!=-888].Survived.value_counts().plot(kind='bar')

# %%
df[df.Survived!=-888].Survived.value_counts().plot(kind='box')

# %%
df[df.Survived!=-888].Survived.value_counts().plot(kind='hist')

# %%
df.Pclass.value_counts().plot(kind='bar',rot=0,title='Class wise Passenger Plot');

# %%
df.Age.plot(kind='hist',title='Age Plot');

# %%
df.Age.plot(kind='hist',title='Age Plot',bins=20);

# %%
df.Age.plot(kind='kde',title='Age Density Plot');

# %%
print("skewness for age: {0:.2f}".format(df.Age.skew()))
print("skewness for fare: {0:.2f}".format(df.Fare.skew()))
# Out:
# skewness for age: 0.41
# skewness for fare: 4.37

# %%
df.plot.scatter(x='Age',y='Fare',title='AgevsFare');

# %%
df.plot.scatter(x='Age',y='Fare',title='AgevsFare',alpha=0.1);

# %%
df.plot.scatter(x='Pclass',y='Fare',title='{PclassvsFare');

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df.groupby('Pclass').Fare.median()
# Out:
# Pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass').Age.median()
# Out:
# Pclass
# 1    39.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df.groupby('Pclass')['Age','Fare'].median()
# Out:
#          Age     Fare
# Pclass
# 1       39.0  60.0000
# 2       29.0  15.0458
# 3       24.0   8.0500

# %%
df.groupby('Pclass').agg({'Age':'median','Fare':'mean'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
Aggregate={
    'Fare':{
        'mean_fare':'mean',
        'median_fare':'median',
        'max_fare':max,
        'min_fare':np.min
    },
    'Age':{
        'median_age':'median',
        'min_age':min,
        'max_age':max,
        'range':lambda x:max(x)-min(x)
    }
}

# %%
df.groupby('Pclass').agg(Aggregate)
# Out:
# /home/deepanshu/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#              Fare                                    Age                    \
#         mean_fare  max_fare median_fare min_fare max_age  range median_age
# Pclass
# 1       87.508992  512.3292     60.0000      0.0    80.0  79.08       39.0
# 2       21.179196   73.5000     15.0458      0.0    70.0  69.33       29.0
# 3       13.302889   69.5500      8.0500      0.0    74.0  73.83       24.0
#
#
#        min_age
# Pclass
# 1         0.92
# 2         0.67
# 3         0.17

# %%
df.groupby(['Pclass','Embarked','Sex']).Fare.mean()
# Out:
# Pclass  Embarked  Sex
# 1       C         female    118.895949
#                   male       94.622560
#         Q         female     90.000000
#                   male       90.000000
#         S         female    101.069145
#                   male       53.670756
# 2       C         female     27.003791
#                   male       20.904406
#         Q         female     12.350000
#                   male       11.489160
#         S         female     23.023118
#                   male       20.073322
# 3       C         female     13.834545
#                   male        9.775901
#         Q         female      9.791968
#                   male       10.979167
#         S         female     18.083851
#                   male       13.145977
# Name: Fare, dtype: float64

# %%
pd.crosstab(df.Pclass,df.Sex)
# Out:
# Sex     female  male
# Pclass
# 1          144   179
# 2          106   171
# 3          216   493

# %%
pd.crosstab(df.Sex,df.Pclass).plot(kind='bar',rot=0);

# %%
df.pivot_table(index='Sex',columns='Pclass',values='Age',aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df.groupby(['Sex','Pclass']).Age.mean()
# Out:
# Sex     Pclass
# female  1         37.037594
#         2         27.499223
#         3         22.185329
# male    1         41.029272
#         2         30.815380
#         3         25.962264
# Name: Age, dtype: float64

# %%
df.groupby(['Sex','Pclass']).Age.mean().unstack()
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df1=df.groupby('Sex')
df1.head(10)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
# 11            4.0    G6        S  16.7000
# 12           58.0  C103        S  26.5500
# 13           20.0   NaN        S   8.0500
# 14           39.0   NaN        S  31.2750
# 15           14.0   NaN        S   7.8542
# 16           55.0   NaN        S  16.0000
# 17            2.0   NaN        Q  29.1250
# 18            NaN   NaN        S  13.0000
# 19           31.0   NaN        S  18.0000
# 21           35.0   NaN        S  26.0000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Embarked.isnull()]
# Out:
#               Age Cabin Embarked  Fare  \
# PassengerId
# 62           38.0   B28      NaN  80.0
# 830          62.0   B28      NaN  80.0
#
#                                                   Name  Parch  Pclass     Sex  \
# PassengerId
# 62                                 Icard, Miss. Amelie      0       1  female
# 830          Stone, Mrs. George Nelson (Martha Evelyn)      0       1  female
#
#              SibSp  Survived  Ticket
# PassengerId
# 62               0         1  113572
# 830              0         1  113572

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
df.Embarked.fillna('C',inplace=True)

# %%
df[df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Fare.isnull()]
# Out:
#               Age Cabin Embarked  Fare                Name  Parch  Pclass  \
# PassengerId
# 1044         60.5   NaN        S   NaN  Storey, Mr. Thomas      0       3
#
#               Sex  SibSp  Survived Ticket
# PassengerId
# 1044         male      0      -888   3701

# %%
df.groupby(['Pclass','Embarked','Sex']).Fare.median()
# Out:
# Pclass  Embarked  Sex
# 1       C         female    83.15830
#                   male      62.66875
#         Q         female    90.00000
#                   male      90.00000
#         S         female    78.85000
#                   male      35.50000
# 2       C         female    27.72080
#                   male      15.04580
#         Q         female    12.35000
#                   male      12.35000
#         S         female    23.00000
#                   male      13.00000
# 3       C         female    14.45420
#                   male       7.22920
#         Q         female     7.75000
#                   male       7.75000
#         S         female    13.77500
#                   male       8.05000
# Name: Fare, dtype: float64

# %%
median_fare=df.loc[(df.Pclass==3)&(df.Embarked=='S'),'Fare'].median()

# %%
df.Fare.fillna(median_fare,inplace=True)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Age.isnull()]
# Out:
#              Age  Cabin Embarked      Fare  \
# PassengerId
# 6            NaN    NaN        Q    8.4583
# 18           NaN    NaN        S   13.0000
# 20           NaN    NaN        C    7.2250
# 27           NaN    NaN        C    7.2250
# 29           NaN    NaN        Q    7.8792
# 30           NaN    NaN        S    7.8958
# 32           NaN    B78        C  146.5208
# 33           NaN    NaN        Q    7.7500
# 37           NaN    NaN        C    7.2292
# 43           NaN    NaN        C    7.8958
# 46           NaN    NaN        S    8.0500
# 47           NaN    NaN        Q   15.5000
# 48           NaN    NaN        Q    7.7500
# 49           NaN    NaN        C   21.6792
# 56           NaN    C52        S   35.5000
# 65           NaN    NaN        C   27.7208
# 66           NaN    NaN        C   15.2458
# 77           NaN    NaN        S    7.8958
# 78           NaN    NaN        S    8.0500
# 83           NaN    NaN        Q    7.7875
# ...

# %%
df[df.Age.isnull()==False].Age.plot(kind='hist');

# %%
df[df.Age.isnull()==False].Age.mean()
# Out:
# 29.881137667304014

# %%
df.groupby('Sex').Age.mean()
# Out:
# Sex
# female    28.687088
# male      30.585228
# Name: Age, dtype: float64

# %%
df.Age.plot(kind='box')

# %%
df[df.Age.notnull()].boxplot('Age','Sex');

# %%
df[df.Age.notnull()].boxplot('Age','Pclass');

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
# 8                          Palsson, Master. Gosta Leonard
# 9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                        Sandstrom, Miss. Marguerite Rut
# 12                               Bonnell, Miss. Elizabeth
# 13                         Saundercock, Mr. William Henry
# 14                            Andersson, Mr. Anders Johan
# 15                   Vestrom, Miss. Hulda Amanda Adolfina
# 16                       Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
def GetTitle(name):
    temp1=name.split(',')[1]
    temp2=temp1.split('.')[0]
    temp=temp2.strip().lower()
    return temp

# %%
df.Name.map(lambda x:GetTitle(x))
# Out:
# PassengerId
# 1           mr
# 2          mrs
# 3         miss
# 4          mrs
# 5           mr
# 6           mr
# 7           mr
# 8       master
# 9          mrs
# 10         mrs
# 11        miss
# 12        miss
# 13          mr
# 14          mr
# 15        miss
# 16         mrs
# 17      master
# 18          mr
# 19         mrs
# 20         mrs
# 21          mr
# 22          mr
# 23        miss
# 24          mr
# 25        miss
# 26         mrs
# 27          mr
# 28          mr
# 29        miss
# 30          mr
#          ...
# 1280        mr
# 1281    master
# 1282        mr
# 1283       mrs
# 1284    master
# 1285        mr
# 1286        mr
# 1287       mrs
# 1288        mr
# 1289       mrs
# 1290        mr
# 1291        mr
# 1292      miss
# 1293        mr
# 1294      miss
# 1295        mr
# 1296        mr
# 1297        mr
# 1298        mr
# 1299        mr
# 1300      miss
# 1301      miss
# 1302      miss
# 1303       mrs
# 1304      miss
# 1305        mr
# 1306      dona
# ...

# %%
df.Name.map(lambda x: GetTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer', 'dona'], dtype=object)

# %%
def GetTitle(name):
    title_group={
        'mr':'Mr',
        'mrs':'Mrs',
        'miss':'Miss',
        'master':'Master',
        'don':'sir',
        'rev':'sir',
        'dr':'Officer',
        'mme':'Mrs',
        'ms':'Mrs',
        'major':'Officer',
        'lady':'Lady',
        'sir':'Sir',
        'mlle':'Miss',
        'col':'Officer',
        'capt':'Officer',
        'the countess':'Lady',
        'jonkheer':'Sir',
        'dona':'Lady'
    }
    temp1=name.split(',')[1]
    temp2=temp1.split('.')[0]
    temp=temp2.strip().lower()
    return title_group[temp]

# %%
df.Name.map(lambda x:GetTitle(x))
# Out:
# PassengerId
# 1           Mr
# 2          Mrs
# 3         Miss
# 4          Mrs
# 5           Mr
# 6           Mr
# 7           Mr
# 8       Master
# 9          Mrs
# 10         Mrs
# 11        Miss
# 12        Miss
# 13          Mr
# 14          Mr
# 15        Miss
# 16         Mrs
# 17      Master
# 18          Mr
# 19         Mrs
# 20         Mrs
# 21          Mr
# 22          Mr
# 23        Miss
# 24          Mr
# 25        Miss
# 26         Mrs
# 27          Mr
# 28          Mr
# 29        Miss
# 30          Mr
#          ...
# 1280        Mr
# 1281    Master
# 1282        Mr
# 1283       Mrs
# 1284    Master
# 1285        Mr
# 1286        Mr
# 1287       Mrs
# 1288        Mr
# 1289       Mrs
# 1290        Mr
# 1291        Mr
# 1292      Miss
# 1293        Mr
# 1294      Miss
# 1295        Mr
# 1296        Mr
# 1297        Mr
# 1298        Mr
# 1299        Mr
# 1300      Miss
# 1301      Miss
# 1302      Miss
# 1303       Mrs
# 1304      Miss
# 1305        Mr
# 1306      Lady
# ...

# %%
df['Title']=df.Name.map(lambda x:GetTitle(x))

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title
# PassengerId
# 1              male      1         0         A/5 21171    Mr
# 2            female      1         1          PC 17599   Mrs
# ...

# %%
df[df.Age.notnull()].boxplot('Age','Title');

# %%
med_age=df.groupby('Title').Age.transform('median')
df.Age.fillna(med_age,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# Title       1309 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 172.9+ KB

# %%
df.Age.plot(kind='hist');

# %%
df[df.Age>70]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q   7.7500
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S  30.0000
# 852          74.0   NaN        S   7.7750
# 988          76.0   C46        S  78.8500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# ...

# %%
df.Fare.plot(kind='hist',bins=20);

# %%
df.Fare.plot(kind='box');

# %%
df[df.Fare==df.Fare.max()]
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 259          35.0          NaN        C  512.3292
# 680          36.0  B51 B53 B55        C  512.3292
# 738          35.0         B101        C  512.3292
# 1235         58.0  B51 B53 B55        C  512.3292
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# 259          female      0         1  PC 17755  Miss
# 680            male      0         1  PC 17755    Mr
# 738            male      0         1  PC 17755    Mr
# 1235         female      0      -888  PC 17755   Mrs

# %%
log_fare=np.log(df.Fare+1)

# %%
log_fare.plot(kind='hist',bins=20);

# %%
pd.qcut(df.Fare,4)
# Out:
# PassengerId
# 1         (-0.001, 7.896]
# 2       (31.275, 512.329]
# 3         (7.896, 14.454]
# 4       (31.275, 512.329]
# 5         (7.896, 14.454]
# 6         (7.896, 14.454]
# 7       (31.275, 512.329]
# 8        (14.454, 31.275]
# 9         (7.896, 14.454]
# 10       (14.454, 31.275]
# 11       (14.454, 31.275]
# 12       (14.454, 31.275]
# 13        (7.896, 14.454]
# 14       (14.454, 31.275]
# 15        (-0.001, 7.896]
# 16       (14.454, 31.275]
# 17       (14.454, 31.275]
# 18        (7.896, 14.454]
# 19       (14.454, 31.275]
# 20        (-0.001, 7.896]
# 21       (14.454, 31.275]
# 22        (7.896, 14.454]
# 23        (7.896, 14.454]
# 24      (31.275, 512.329]
# 25       (14.454, 31.275]
# 26      (31.275, 512.329]
# 27        (-0.001, 7.896]
# 28      (31.275, 512.329]
# 29        (-0.001, 7.896]
# 30        (-0.001, 7.896]
#               ...
# 1280      (-0.001, 7.896]
# 1281     (14.454, 31.275]
# 1282    (31.275, 512.329]
# 1283    (31.275, 512.329]
# ...

# %%
df1=pd.qcut(df.Fare,4,labels=['very low','low','high','very high'])

# %%
df1.value_counts()
# Out:
# very low     337
# high         328
# very high    323
# low          321
# Name: Fare, dtype: int64

# %%
df1.value_counts().plot(kind='bar',rot=0);

# %%
df['Fare_bin']=df1

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title   Fare_bin
# PassengerId
# 1              male      1         0         A/5 21171    Mr   very low
# ...

# %%
df['Age_State']=np.where(df['Age']>=18,'Adults','Child')

# %%
df['Age_State'].value_counts()
# Out:
# Adults    1147
# Child      162
# Name: Age_State, dtype: int64

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Age_State)
# Out:
# Age_State  Adults  Child
# Survived
# 0             495     54
# 1             279     63

# %%
df['family_size']=df.Parch+df.SibSp+1

# %%
df['family_size'].plot(kind='bar',rot=0);

# %%
df['family_size'].plot(kind='hist',bins=20);

# %%
df[df.family_size==df.family_size.max()]
# Out:
#               Age Cabin Embarked   Fare                               Name  \
# PassengerId
# 160           4.0   NaN        S  69.55         Sage, Master. Thomas Henry
# 181          22.0   NaN        S  69.55       Sage, Miss. Constance Gladys
# 202          29.0   NaN        S  69.55                Sage, Mr. Frederick
# 325          29.0   NaN        S  69.55           Sage, Mr. George John Jr
# 793          22.0   NaN        S  69.55            Sage, Miss. Stella Anna
# 847          29.0   NaN        S  69.55           Sage, Mr. Douglas Bullen
# 864          22.0   NaN        S  69.55  Sage, Miss. Dorothy Edith "Dolly"
# 1080         22.0   NaN        S  69.55                    Sage, Miss. Ada
# 1234         29.0   NaN        S  69.55              Sage, Mr. John George
# 1252         14.5   NaN        S  69.55        Sage, Master. William Henry
# 1257         35.0   NaN        S  69.55     Sage, Mrs. John (Annie Bullen)
#
# ...

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].family_size)
# Out:
# family_size   1   2   3   4   5   6   7   8   11
# Survived
# 0            374  72  43   8  12  19   8   6   7
# 1            163  89  59  21   3   3   4   0   0

# %%
df['isMother']=np.where((df.Sex=='female')&(df.Parch>0)&(df.Age>18)&(df.Title!='Miss'),1,0)

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].isMother)
# Out:
# isMother    0   1
# Survived
# 0         533  16
# 1         303  39

# %%
df.Cabin
# Out:
# PassengerId
# 1               NaN
# 2               C85
# 3               NaN
# 4              C123
# 5               NaN
# 6               NaN
# 7               E46
# 8               NaN
# 9               NaN
# 10              NaN
# 11               G6
# 12             C103
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              D56
# 23              NaN
# 24               A6
# 25              NaN
# 26              NaN
# 27              NaN
# 28      C23 C25 C27
# 29              NaN
# 30              NaN
#            ...
# 1280            NaN
# 1281            NaN
# 1282            B24
# 1283            D28
# 1284            NaN
# 1285            NaN
# 1286            NaN
# 1287            C31
# 1288            NaN
# 1289            B41
# 1290            NaN
# 1291            NaN
# 1292             C7
# 1293            NaN
# ...

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.loc[df.Cabin=='T',:]
# Out:
#               Age Cabin Embarked  Fare                          Name  Parch  \
# PassengerId
# 340          45.0     T        S  35.5  Blackwell, Mr. Stephen Weart      0
#
#              Pclass   Sex  SibSp  Survived  Ticket Title   Fare_bin Age_State  \
# PassengerId
# 340               1  male      0         0  113784    Mr  very high    Adults
#
#              family_size  isMother
# PassengerId
# 340                    1         0

# %%
df.loc[df.Cabin=='T','Cabin']=np.NaN

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34',
#        'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37',
#        'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39',
#        'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41',
#        'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58',
# ...

# %%
def getDeck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
df['Deck']=df.Cabin.map(lambda x:getDeck(x))

# %%
df.head(10)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6            29.0   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...

# %%
df.Deck.value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
df.Deck.value_counts().plot(kind='bar',rot=0);

# %%
pd.crosstab(df[df.Survived!=-888].Survived,df[df.Survived!=-888].Deck)
# Out:
# Deck      A   B   C   D   E  F  G    Z
# Survived
# 0         8  12  24   8   8  5  2  482
# 1         7  35  35  25  24  8  2  206

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
# Age            1309 non-null float64
# Cabin          294 non-null object
# Embarked       1309 non-null object
# Fare           1309 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       1309 non-null int64
# Ticket         1309 non-null object
# Title          1309 non-null object
# Fare_bin       1309 non-null category
# Age_State      1309 non-null object
# family_size    1309 non-null int64
# isMother       1309 non-null int64
# Deck           1309 non-null object
# dtypes: category(1), float64(2), int64(6), object(8)
# memory usage: 215.3+ KB

# %%
df['isMale']=np.where(df.Sex=='male',1,0)

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title   Fare_bin  \
# PassengerId
# 1              male      1         0         A/5 21171    Mr   very low
# ...

# %%
df=pd.get_dummies(df,columns=['Embarked','Deck','Pclass','Title','Fare_bin','Age_State'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 40 columns):
# Age                   1309 non-null float64
# Cabin                 294 non-null object
# Fare                  1309 non-null float64
# Name                  1309 non-null object
# Parch                 1309 non-null int64
# Sex                   1309 non-null object
# SibSp                 1309 non-null int64
# Survived              1309 non-null int64
# Ticket                1309 non-null object
# family_size           1309 non-null int64
# isMother              1309 non-null int64
# isMale                1309 non-null int64
# Embarked_C            1309 non-null uint8
# Embarked_Q            1309 non-null uint8
# Embarked_S            1309 non-null uint8
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# ...

# %%
df.drop(['Cabin','Name','Parch','Sex','SibSp','Ticket'],axis=1,inplace=True)

# %%
columns=[column for column in df.columns if column!='Survived']
columns=['Survived']+columns
df=df[columns]

# %%
df.head(10)
# Out:
#              Survived   Age     Fare  family_size  isMother  isMale  \
# PassengerId
# 1                   0  22.0   7.2500            2         0       1
# 2                   1  38.0  71.2833            2         0       0
# 3                   1  26.0   7.9250            1         0       0
# 4                   1  35.0  53.1000            2         0       0
# 5                   0  35.0   8.0500            1         0       1
# 6                   0  29.0   8.4583            1         0       1
# 7                   0  54.0  51.8625            1         0       1
# 8                   0   2.0  21.0750            5         0       1
# 9                   1  27.0  11.1333            3         1       0
# 10                  1  14.0  30.0708            2         0       0
#
#              Embarked_C  Embarked_Q  Embarked_S  Deck_A       ...         \
# PassengerId                                                   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 34 columns):
# Survived              1309 non-null int64
# Age                   1309 non-null float64
# Fare                  1309 non-null float64
# family_size           1309 non-null int64
# isMother              1309 non-null int64
# isMale                1309 non-null int64
# Embarked_C            1309 non-null uint8
# Embarked_Q            1309 non-null uint8
# Embarked_S            1309 non-null uint8
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# Pclass_1              1309 non-null uint8
# Pclass_2              1309 non-null uint8
# Pclass_3              1309 non-null uint8
# ...

# %%
processed_data_path=os.path.join(os.path.pardir,'data','processed')
write_train_path=os.path.join(processed_data_path,'train.csv')
write_test_path=os.path.join(processed_data_path,'test.csv')

# %%
df.loc[df.Survived!=-888].to_csv(write_train_path)
columns=[column for column in df.columns if column!='Survived']
df.loc[df.Survived==-888,columns].to_csv(write_test_path)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df.Age,bins=20)
# Out:
# (array([ 59.,  21.,  22.,  40., 114., 210., 128., 298., 125.,  64.,  51.,
#          57.,  39.,  27.,  21.,  20.,   5.,   5.,   2.,   1.]),
#  array([ 0.17  ,  4.1615,  8.153 , 12.1445, 16.136 , 20.1275, 24.119 ,
#         28.1105, 32.102 , 36.0935, 40.085 , 44.0765, 48.068 , 52.0595,
#         56.051 , 60.0425, 64.034 , 68.0255, 72.017 , 76.0085, 80.    ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(df.Age,bins=20)
plt.xlabel('Bins')
plt.ylabel('Age')
plt.title('Age Plot')
plt.show()

# %% [markdown]
# #Building Predictive Models

# %%
processed_data_path=os.path.join(os.path.pardir,'data','processed')
train_file_path=os.path.join(processed_data_path,'train.csv')
test_file_path=os.path.join(processed_data_path,'test.csv')

# %%
train_df=pd.read_csv(train_file_path,index_col='PassengerId')
test_df=pd.read_csv(test_file_path,index_col='PassengerId')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 34 columns):
# Survived              891 non-null int64
# Age                   891 non-null float64
# Fare                  891 non-null float64
# family_size           891 non-null int64
# isMother              891 non-null int64
# isMale                891 non-null int64
# Embarked_C            891 non-null int64
# Embarked_Q            891 non-null int64
# Embarked_S            891 non-null int64
# Deck_A                891 non-null int64
# Deck_B                891 non-null int64
# Deck_C                891 non-null int64
# Deck_D                891 non-null int64
# Deck_E                891 non-null int64
# Deck_F                891 non-null int64
# Deck_G                891 non-null int64
# Deck_Z                891 non-null int64
# Pclass_1              891 non-null int64
# Pclass_2              891 non-null int64
# Pclass_3              891 non-null int64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 33 columns):
# Age                   418 non-null float64
# Fare                  418 non-null float64
# family_size           418 non-null int64
# isMother              418 non-null int64
# isMale                418 non-null int64
# Embarked_C            418 non-null int64
# Embarked_Q            418 non-null int64
# Embarked_S            418 non-null int64
# Deck_A                418 non-null int64
# Deck_B                418 non-null int64
# Deck_C                418 non-null int64
# Deck_D                418 non-null int64
# Deck_E                418 non-null int64
# Deck_F                418 non-null int64
# Deck_G                418 non-null int64
# Deck_Z                418 non-null int64
# Pclass_1              418 non-null int64
# Pclass_2              418 non-null int64
# Pclass_3              418 non-null int64
# Title_Lady            418 non-null int64
# ...

# %%
X=train_df.loc[:,'Age':].as_matrix().astype('float')
y=train_df['Survived'].ravel()

# %%
X.shape
# Out:
# (891, 33)

# %%
print(y.shape)
# Out:
# (891,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
# Out:
# (712, 33)

# %%
print(y_train.shape)
# Out:
# (712,)

# %%
print(X_test.shape)
# Out:
# (179, 33)

# %%
print(y_test.shape)
# Out:
# (179,)

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.19.1'

# %%
from sklearn.dummy import DummyClassifier

# %%
model_dummy=DummyClassifier(strategy='most_frequent',random_state=0)
model_dummy.fit(X_train,y_train)
# Out:
# DummyClassifier(constant=None, random_state=0, strategy='most_frequent')

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, y_train) * 100, 2)
acc_log
# Out:
# 83.99

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, y_train) * 100, 2)
acc_svc
# Out:
# 87.08

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, y_train) * 100, 2)
acc_knn
# Out:
# 83.85

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
random_forest.score(X_test, y_test)
acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 2)
acc_random_forest
# Out:
# 83.8

# %%
submission=pd.DataFrame({
    "PassengerId":X_test[:,0],
    "Survived":y_pred
})
