# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
obj=df.copy()

# %%
obj.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
obj=obj.drop('date',axis=1)

# %%
obj.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
col=['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15', 'price']

obj=obj[['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15','price']]

# %%
obj.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
obj.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   4.580302e+09      3.370842      2.114757   2079.899736  1.510697e+04
# std    2.876566e+09      0.930062      0.770163    918.440897  4.142051e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068800e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df.plot.scatter(x='sqft_above',y='price',c='DarkBlue')

# %%
obj.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df.zipcode,df.price)

# %%
plt.scatter(df.floors,df.price)
plt.title("Floors vs Price")
# Out:
# Text(0.5,1,'Floors vs Price')

# %%
y=pd.DataFrame(data=obj['price'],index=None,columns=['price'])

# %%
y.head()
# Out:
#       price
# 0  221900.0
# 1  538000.0
# 2  180000.0
# 3  604000.0
# 4  510000.0

# %%
obj.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
X=obj.copy()

# %%
X.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
X.yr_built=X.yr_built>=2000

# %%
X=X.applymap(lambda x: 1 if x == True else x)
X=X.applymap(lambda x: 0 if x == False else x)

# %%
X.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0         0             0
# 1     0          3      7        2170            400         0          1991
# 2     0          3      6         770              0         0             0
# 3     0          5      7        1050            910         0             0
# 4     0          3      8        1680              0         0             0
#
# ...

# %%
X=X.drop('price',axis=1)

# %%
X.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0         0             0
# 1     0          3      7        2170            400         0          1991
# 2     0          3      6         770              0         0             0
# 3     0          5      7        1050            910         0             0
# 4     0          3      8        1680              0         0             0
#
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X, y,test_size=0.1)

# %%
X_train.head()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20533  1545808120         3       2.00         1590      8100     1.0
# 18118  7589200165         3       2.50         1820      5280     1.0
# 14374  3043200035         2       1.00          910      2002     1.5
# 8706   3876312370         3       1.75         1930      7210     1.0
# 12954  3331001165         3       1.00          820      5150     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 20533           0     0          3      7        1060            530
# 18118           0     0          4      7         910            910
# 14374           0     0          3      6         910              0
# 8706            0     0          3      7        1110            820
# 12954           0     0          5      6         820              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
y_train.head()
# Out:
#           price
# 20533  250000.0
# 18118  515000.0
# 14374  600000.0
# 8706   434500.0
# 12954  305000.0

# %%
X_test.head()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 13913  3558900580         3       2.50         2000      8424     1.0
# 11173  6683000295         3       2.50         2010     14298     2.0
# 4681   1189000645         4       2.00         1930      3976     1.5
# 17117  7625701045         3       1.75         1510      6000     1.0
# 12166  1498303855         4       2.75         2930      4408     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 13913           0     0          4      7        1300            700
# 11173           0     0          3      7        2010              0
# 4681            0     0          4      8        1930              0
# 17117           0     0          3      7        1060            450
# 12166           0     0          5      8        1660           1270
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
y_test.head()
# Out:
#           price
# 13913  470000.0
# 11173  350000.0
# 4681   650000.0
# 17117  360000.0
# 12166  718000.0

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression().fit(X_train,y_train)

# %%
model.score(X_train,y_train)
# Out:
# 0.6814431593240243

# %%
model.coef_
# Out:
# array([[-1.17682059e-06, -3.19994369e+04,  4.88958861e+03,
#          1.22626917e+02,  2.05991407e-01, -2.13851225e+04,
#          5.81073968e+05,  5.90018994e+04,  5.17527346e+04,
#          7.91090896e+04,  7.79785350e+01,  4.46483819e+01,
#         -6.33260148e+03,  6.07099639e+01, -4.29068067e+02,
#          6.74056189e+05, -3.23393637e+05,  2.43618378e+01,
#         -4.48692182e-01]])

# %%
y_hat=model.predict(X_test)

# %%
y_hat
# Out:
# array([[611100.51306676],
#        [491784.6110416 ],
#        [570350.54466716],
#        ...,
#        [420438.79809895],
#        [735979.27827523],
#        [854535.78609625]])

# %%
len(y_hat)
# Out:
# 2162

# %%
len(y_test)
# Out:
# 2162

# %%
from sklearn.metrics import explained_variance_score

# %%
var_score=explained_variance_score(y_test, y_hat)

# %%
var_score
# Out:
# 0.6847149229478602

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_abs_error=mean_absolute_error(y_test, y_hat)

# %%
mean_abs_error
# Out:
# 131621.68282080945

# %%
from sklearn.ensemble import GradientBoostingRegressor as gbr

# %%
model1=gbr(n_estimators=400,max_depth=5,min_samples_split=2,learning_rate=0.1,loss='ls')

# %%
model1.fit(X_train,y_train)
# Out:
# /home/deepanshu/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=5, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=400, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
res=model1.score(X_test,y_test)

# %%
print(res)
# Out:
# 0.9052355404112152
